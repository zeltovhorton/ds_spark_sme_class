# %% [markdown]
# # Lab 14: Using K-means clustering to identify crime hot-spots

# %% [markdown]
# As always, setup a Spark Context and HiveContext:

# %%
# Set up Spark Context
from pyspark import SparkContext, SparkConf

SparkContext.setSystemProperty('spark.executor.memory', '2g')
conf = SparkConf()
conf.set('spark.executor.instances', 15)
sc = SparkContext('yarn-client', 'Spark-lab14', conf=conf)

from pyspark.sql import HiveContext
hc = HiveContext(sc)
hc.sql("use demo")
# Out:
# DataFrame[result: string]

# %% [markdown]
# From the "crimes" table create a Spark RDD.
# * Each element of the RDD should hold a NumPy array with two values: longitude and latitude of the crime event.
# * Recall how some events have invalid longitude/latitude values - remove any events with invalid longitude/latitude values.

# %%
from numpy import array
crimes = hc.table('crimes').filter('latitude > 37 and latitude < 38') \
           .map(lambda row: array([float(row.longitude), float(row.latitude)])).cache()

# %% [markdown]
# Use ML-Lib's K-means clustering algorithm to cluster the data into either 10 clusters (1 per district) or 37 clusters (1 per neighborhood):

# %%
from pyspark.mllib.clustering import KMeans, KMeansModel
from math import sqrt

numClusters = 37   # Or 10 if you so choose
clusters = KMeans.train(crimes, numClusters, maxIterations=20, runs=10, initializationMode="k-means||")

# %% [markdown]
# In clustering, a popular measure to evaluate the compactness of clusters is the Within-Set-Sum-Of-Squared-Error (aka WSSSE). We will not compute this metric for our clustering result

# %%
# Evaluate clustering by computing Within Set Sum of Squared Errors
def error(point):
    center = clusters.centers[clusters.predict(point)]
    return sqrt(sum([x**2 for x in (point - center)]))

mean_WSSSE = crimes.map(lambda point: error(point)).reduce(lambda x, y: x + y) / float(crimes.count())
print("Within Set Sum of Squared Error = " + str(mean_WSSSE))
# Out:
# Within Set Sum of Squared Error = 0.0047798139527

# %% [markdown]
# We now define again the helper functions for map drawing with Folium:

# %%
from IPython.display import HTML
map_width=1000
map_height=600

def inline_map(m, width=map_width, height=map_height):
    m.create_map()
    srcdoc = m.HTML.replace('"', '&quot;')
    embed = HTML('<iframe srcdoc="{}" '
                 'style="width: {}px; height: {}px; '
                 'border: none"></iframe>'.format(srcdoc, width, height))
    return embed

# %% [markdown]
# Use Spark and the resulting clusters to create a Pandas dataframe that counts the number of data points that belong to each cluster.

# %%
import pandas as pd

cdata = crimes.map(lambda point: (clusters.predict(point), 1)) \
               .reduceByKey(lambda a,b: a+b).collect()
counts = pd.DataFrame(cdata, columns=['cluster', 'count']).set_index('cluster')['count'].to_dict()

# %% [markdown]
# Plot a map of SF using Folium and add a marker at each crime hotspot, showing the number of crimes in that centroid

# %%
import folium

sf_lat = 37.77
sf_long = -122.4

map_sf = folium.Map(location=[sf_lat, sf_long], zoom_start=12, width=map_width, height=map_height)
for cl,ctr in enumerate(clusters.centers):
    num = counts[cl]
    map_sf.circle_marker(location=[ctr[1], ctr[0]], radius = num/300, 
                         popup = "hotspot %d, n = %d" % (cl, num),
                         line_color='#3186cc', fill_color='#3186cc', fill_opacity=0.5)
inline_map(map_sf)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <head>
#    <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.css&quot; />
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet/0.7.3/leaflet.js&quot;></script>
#
#    <script src=&quot;//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;>
#    <script src=&quot;//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#
#    <link href=&quot;//maxcdn.bootstrapcdn.com/font-awesome/4.1.0/css/font-awesome.min.css&quot; rel=&quot;stylesheet&quot;>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//rawgit.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.css&quot;>
#    <script src=&quot;//rawgithub.com/lvoogdt/Leaflet.awesome-markers/2.0/develop/dist/leaflet.awesome-markers.js&quot;></script>
#
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.Default.css&quot;>
#    <link rel=&quot;stylesheet&quot; href=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/MarkerCluster.css&quot;>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster-src.js&quot;></script>
#    <script src=&quot;//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/0.4.0/leaflet.markercluster.js&quot;></script>
#
#    <link rel=&quot;stylesheet&quot; href=&quot;//birdage.github.io/Leaflet.awesome-markers/dist/leaflet.awesome.rotate.css&quot;>
#
#
#
#
#
#
#    <style>
#
#       html, body {
#         width: 100%;
#         height: 100%;
#         margin: 0;
#         padding: 0;
#       }
#
#       #map {
#         position:absolute;
#         top:0;
#         bottom:0;
#         right:0;
#         left:0;
#       }
#
#    </style>
# </head>
#
# <body>
#
#    <div class=&quot;folium-map&quot; id=&quot;folium_b36acebc0b5c4bcebc3d694a326c671d&quot; style=&quot;width: 1000px; height: 600px&quot;></div>
#
#    <script>
#
#
#
#       var base_tile = L.tileLayer('http://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', {
#           maxZoom: 18,
#           minZoom: 1,
#           attribution: 'Map data (c) <a href=&quot;http://openstreetmap.org&quot;>OpenStreetMap</a> contributors'
#       });
#
#       var baseLayer = {
#         &quot;Base Layer&quot;: base_tile
#       };
#
#       /*
#       addition of the wms layers
#       */
#
#
#
#       /*
#       addition of the tile layers
#       */
#
#
#       /*
#       list of layers to be added
#       */
#       var layer_list = {
#
#       };
#
#       /*
#       Bounding box.
#       */
#       var southWest = L.latLng(-90, -180),
#           northEast = L.latLng(90, 180),
#           bounds = L.latLngBounds(southWest, northEast);
#
#       /*
#       Creates the map and adds the selected layers
#       */
#       var map = L.map('folium_b36acebc0b5c4bcebc3d694a326c671d', {
#                                        center:[37.77, -122.4],
#                                        zoom: 12,
#                                        maxBounds: bounds,
#                                        layers: [base_tile]
#                                      });
#
#       L.control.layers(baseLayer, layer_list).addTo(map);
#
#       //cluster group
#       var clusteredmarkers = L.markerClusterGroup();
#       //section for adding clustered markers
#
#       //add the clustered markers to the group anyway
#       map.addLayer(clusteredmarkers);
#
#
#
#
#       var circle_1 = L.circle([37.7847925008, -122.408929861], 673, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_1.bindPopup(&quot;hotspot 0, n = 202167&quot;);
#       circle_1._popup.options.maxWidth = 300;
#       map.addLayer(circle_1)
#
#       var circle_2 = L.circle([37.7728034604, -122.424688149], 190, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_2.bindPopup(&quot;hotspot 1, n = 57056&quot;);
#       circle_2._popup.options.maxWidth = 300;
#       map.addLayer(circle_2)
#
#       var circle_3 = L.circle([37.7223290427, -122.475856339], 90, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_3.bindPopup(&quot;hotspot 2, n = 27098&quot;);
#       circle_3._popup.options.maxWidth = 300;
#       map.addLayer(circle_3)
#
#       var circle_4 = L.circle([37.7183259876, -122.456183544], 138, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_4.bindPopup(&quot;hotspot 3, n = 41543&quot;);
#       circle_4._popup.options.maxWidth = 300;
#       map.addLayer(circle_4)
#
#       var circle_5 = L.circle([37.7792562681, -122.464812644], 107, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_5.bindPopup(&quot;hotspot 4, n = 32353&quot;);
#       circle_5._popup.options.maxWidth = 300;
#       map.addLayer(circle_5)
#
#       var circle_6 = L.circle([37.7967600621, -122.405188204], 212, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_6.bindPopup(&quot;hotspot 5, n = 63750&quot;);
#       circle_6._popup.options.maxWidth = 300;
#       map.addLayer(circle_6)
#
#       var circle_7 = L.circle([37.719700652, -122.395112518], 102, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_7.bindPopup(&quot;hotspot 6, n = 30768&quot;);
#       circle_7._popup.options.maxWidth = 300;
#       map.addLayer(circle_7)
#
#       var circle_8 = L.circle([37.7753895213, -122.504545364], 38, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_8.bindPopup(&quot;hotspot 7, n = 11601&quot;);
#       circle_8._popup.options.maxWidth = 300;
#       map.addLayer(circle_8)
#
#       var circle_9 = L.circle([37.7354166965, -122.391690102], 175, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_9.bindPopup(&quot;hotspot 8, n = 52647&quot;);
#       circle_9._popup.options.maxWidth = 300;
#       map.addLayer(circle_9)
#
#       var circle_10 = L.circle([37.7796034654, -122.484054798], 74, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_10.bindPopup(&quot;hotspot 9, n = 22409&quot;);
#       circle_10._popup.options.maxWidth = 300;
#       map.addLayer(circle_10)
#
#       var circle_11 = L.circle([37.7336058376, -122.407792907], 114, {
#                             color: '#3186cc',
#                             fillColor: '#3186cc',
#                             fillOpacity: 0.5
#                             });
#       circle_11.bindPopup(&quot;hotspot 10, n = 34292&quot;);
#       circle_11._popup.options.maxWidth = 300;
#       map.addLayer(circle_11)
#
#       var circle_12 = L.circle([37.75785
